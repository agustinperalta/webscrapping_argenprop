# %% [markdown]
# <a href="https://colab.research.google.com/github/agustinperalta/webscrapping_argenprop/blob/main/web_scrapping_argenprop_ap.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install unidecode
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: unidecode in /usr/local/lib/python3.8/dist-packages (1.3.6)

# %%
import requests
from unidecode import unidecode
from bs4 import BeautifulSoup

# %%
session = requests.Session()
session.headers.update({'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'})

# %%
'''
This function take an url and call to the API that returns the information of Argentina Provinces, the function return a list only with its name.
'''
def listado_provincias(url):
  try:
    response = session.get(url, timeout=10)
    response.raise_for_status()
    json_data = response.json()
    return [unidecode(prov['nombre'].lower().replace('ciudad autonoma de buenos aires', 'capital federal')) for prov in json_data['provincias'][:-1]]
  except (requests.exceptions.RequestException, ValueError):
    return []

# %%
''' 
This function take the list of Argentine Province & return a list of links to each Province.
'''
def armar_links(provincias):
  URL = "https://www.argenprop.com/departamento-alquiler"
  links = set()
  for prov in provincias:
    link = f"{URL}-provincia-{prov.replace(' ', '-')}{'-arg' if prov not in ('capital federal', 'buenos aires') else ''}"
  links.add(link)
  return list(links)

# %%
''' 
This function takes the paginator element, if is None return -pagina-1 else return a list of strings where each string is Pagina-n, Pagina-n+1 
'''
def range_pages(paginator):
  if paginator:
    pages = paginator.find_all('li', class_='pagination__page')
    pages = [page for page in pages if not 'pagination__page-prev' in page['class'] and not 'pagination__page--disable' in page['class'] and (not 'pagination__page-next' in page['class'])]
    links = [f"-Pagina-{i}" for i in range(int(pages[0].get_text().replace('\n', '').strip()), int(pages[-1].get_text().replace('\n', '').strip())+1)]
  else:
    links = ['-Pagina-1']
  return links

# %%
''' 
This function takes the href url and creates the url to access to the property page.
'''
def build_link_property_page(property_url_link):
  MAIN_PATH =  "https://www.argenprop.com"
  return f"{MAIN_PATH}{property_url_link}"

# %%
''' 
This function takes the property url and if type is bd (building details) then search & return the list with id=section_9 that has the building installations
else if the type is ud (location details) so return the map element that contains the coordinates
'''
def property_page(property_url_link , type):
  page_property = session.get(property_url_link,timeout=10)
  soup_property = BeautifulSoup(page_property.content, "html.parser")
  if type == 'bd':
    building_details = soup_property.find('ul',{'id': 'section_9'}).find_all('li') if soup_property.find('ul',{'id': 'section_9'}) else None
    return building_details if building_details else None
  elif type == 'ud':
    location_details = soup_property.find('div', {'class': 'leaflet-container'}) if soup_property.find('div', {'class': 'leaflet-container'}) else None
    return location_details if location_details else None

# %%
''' 
This function takes the list of building installations, iterate it and return an array of bools that indicates if the building has or not the ammenitie
'''
def extract_building_details(building_details):
  parr = False
  gym = False
  pool = False
  sol = False
  play = False
  sal = False
  asc = False
  if len(building_details) == 0:
    return [parr,gym,pool,sol,play,sal,asc]
  else:
    for element in building_details:
      if element.get_text().replace('\n','').strip() == 'Parrilla':
        parr = True
      elif element.get_text().replace('\n','').strip() == 'Gimnasio':
        gym = True
      elif element.get_text().replace('\n','').strip() == 'Pileta':
        pool = True
      elif element.get_text().replace('\n','').strip() == 'Solarium':
        sol = True
      elif element.get_text().replace('\n','').strip() == 'Juegos para chicos':
        play = True
      elif element.get_text().replace('\n','').strip() == 'Salón de fiestas':
        sal = True
      elif element.get_text().replace('\n','').strip() == 'Ascensor':
        asc = True
    return [parr,gym,pool,sol,play,sal,asc]

# %%
'''
This function takes the location details and if the location details is not null so call to API Geolocation Data to get the Province and department name. Return an array with 3 elements 
'''
def extract_location_details(location_details):
  provincia = None
  departamento = None
  municipio = None
  if location_details:
    latitude = float(location_details['data-latitude'].replace(',','.'))
    longitude = float(location_details['data-longitude'].replace(',','.'))
    data = session.get(f'https://apis.datos.gob.ar/georef/api/ubicacion?lat={latitude}&lon={longitude}',timeout=10)
    if data.status_code == 200:
      data = data.json()
      provincia = data['ubicacion']['provincia']['nombre']
      departamento = data['ubicacion']['departamento']['nombre']
      municipio = data['ubicacion']['municipio']['nombre']
      return  [departamento,provincia, municipio]
    else:
      return  [departamento,provincia, municipio]
  else:
    return [departamento,provincia, municipio]

# %%
'''
This function takes the element ul with the class card__main-features that contains the information about the department such as surface, number of rooms, etc.
And returns a list with the value of each feature.
'''
def extract_property_features(property_features):
  li_elements = property_features.find_all('li')
  sup=''
  dorm=''
  ant=''
  ban = ''
  amb = ''
  coch = ''
  to = ''
  est = ''
  dis = ''
  for li in li_elements:
    i_element = li.find('i')
    if i_element:
      if i_element.attrs.get('class')[0] == 'icono-superficie_cubierta':
        sup = li.text.strip()
      elif i_element.attrs.get('class')[0] == 'icono-cantidad_dormitorios':
        dorm = li.text.strip()
      elif i_element.attrs.get('class')[0] == 'icono-antiguedad':
        ant = li.text.strip()
      elif i_element.attrs.get('class')[0] == 'icono-cantidad_banos':
        ban = li.text.strip()
      elif i_element.attrs.get('class')[0] == 'icono-cantidad_ambientes':
        amb = li.text.strip()
      elif i_element.attrs.get('class')[0] == 'icono-ambiente_cochera':
        coch = li.text.strip()
      elif i_element.attrs.get('class')[0] == 'icono-cantidad_toilettes':
        to = li.text.strip()
      elif i_element.attrs.get('class')[0] == 'icono-estado_propiedad':
        est = li.text.strip()
      elif i_element.attrs.get('class')[0] == 'icono-disposicion':
        dis = li.text.strip()
  properties = [sup,dorm,ant,ban,amb,coch,to,est,dis]
  return properties

# %%
'''
This function takes the element div with class card__monetary-values that contains the main information about the department. 
Return this information as an array.
'''
def extract_main_details(main_details):
  text = main_details.find('p', attrs={"class":"card__price"}).text.replace("\n","").strip()
  span = main_details.find('span', attrs={"class":"card__currency"}).text.replace("\n","").strip()
  span_1 = main_details.find('span', attrs={"class":"card__expenses"}).text.replace("\n","").strip() if main_details.find('span', attrs={"class":"card__expenses"}) else ""
  price = text[len(span):len(span_1)].strip() if span_1 else text[len(span):].strip()
  currency = span
  expenses = span_1
  address = main_details.find("h2", class_="card__address").text.replace("\n","").strip() if main_details.find("h2", class_="card__address") else 'Consultar Dirección'
  title = main_details.find("p", class_="card__title--primary hide-mobile").text.replace("\n","").strip()
  location = main_details.find("p", class_="card__title--primary show-mobile").text.replace("\n","").strip()
  info = [price,currency,expenses,address,title,location]
  return info

# %%
'''
This function takes the link of each province and the list of string that contains the pages for each one.
Return an array with the links for all pages of each provinces. e.g: 'https://www.argenprop.com/departamento-alquiler-provincia-misiones-arg-Pagina-1..n'
'''
def generate_all_pages(link,pages):
  all_pages = []
  for pag in pages:
    all_pages.append(link+pag)
  return all_pages

# %%
'''
This function takes the array of links for each province and for each link search the card department (element div with class 'listening__item'). 
Call to explore_cards function to take information of cards and return an array with the all department information of each provinces.
'''
def explore_page(all_pages):
  properties_prov = []
  for pagina in all_pages:
    page = session.get(pagina,timeout=10)
    soup = BeautifulSoup(page.content, "html.parser")
    cards = soup.find_all("div",class_="listing__item")
    if cards:
      page_info = explore_cards(cards)
      properties_prov.extend(page_info)
  return properties_prov

# %%
'''
This function takes a list of cards and return an array where each element contains information of one card.
'''
def explore_cards(cards):
  page_infos = []
  for card in cards:
    main_details = card.find("div",class_='card__monetary-values')
    property_features = card.find('ul',class_='card__main-features')
    if card.find('a',class_='card'):
      url_link_property = build_link_property_page(card.find('a',class_='card')['href'])
      building_details_list = property_page(url_link_property,type='bd')
      location_details = property_page(url_link_property,type='ud')
      url_property = [build_link_property_page(card.find('a',class_='card')['href'])]
    else:
      continue
    if main_details.find("span",class_="card__noprice"):
      continue
    else:
      details=extract_main_details(main_details)
      properties=extract_property_features(property_features)
      building_details = extract_building_details(building_details_list if building_details_list else [])
      location_details = extract_location_details(location_details if location_details else [])
      info= details + properties + building_details + location_details + url_property if url_property else []
      page_infos.append(info)
  print(page_infos)
  return page_infos

# %%
provincias = listado_provincias('https://infra.datos.gob.ar/catalog/modernizacion/dataset/7/distribution/7.2/download/provincias.json')

# %%
#If you want to run the script with all province uncomment the follow line
#links = armar_links(provincias)
#You will run the script for Cordoba Province in order to try the script
links = armar_links(['cordoba'])

# %%
links
# Out:
# ['https://www.argenprop.com/departamento-alquiler-provincia-cordoba-arg']

# %%
properties_all = []
for link in links:
  page = session.get(link,timeout=10)
  soup = BeautifulSoup(page.content, "html.parser")
  paginator = soup.find('ul',class_='pagination pagination--links')
  pages = range_pages(paginator)
  all_pages = generate_all_pages(link,pages)
  print(all_pages)
  properties = explore_page(all_pages)
  properties_all.extend(properties)
# Out:
# ['https://www.argenprop.com/departamento-alquiler-provincia-cordoba-arg-Pagina-1', 'https://www.argenprop.com/departamento-alquiler-provincia-cordoba-arg-Pagina-2', 'https://www.argenprop.com/departamento-alquiler-provincia-cordoba-arg-Pagina-3', 'https://www.argenprop.com/departamento-alquiler-provincia-cordoba-arg-Pagina-4', 'https://www.argenprop.com/departamento-alquiler-provincia-cordoba-arg-Pagina-5', 'https://www.argenprop.com/departamento-alquiler-provincia-cordoba-arg-Pagina-6']
# [['75.000', '$', '&plus $9.600expensas', 'Duarte Quiros 2500, Piso 6', 'Departamento en Alquiler en Alto Alberdi, Cordoba', 'Alto Alberdi, Cordoba', '52  m² cubie.', '1 dorm.', '5 años', '1 baño', '2 ambientes', '', '', 'Muy Bueno', 'Frente', False, False, False, False, False, False, False, 'Capital', 'Córdoba', 'Córdoba', 'https://www.argenprop.com/departamento-en-alquiler-en-alto-alberdi-2-ambientes--6262241'], ['130.000', '$', '', 'Buenos Aires 400, Piso 5', 'Departamento en Alquiler en Cordoba, Cordoba Capital', 'Cordoba, Cordoba Capital', '', '2 dorm.', '25 años', '2 baños', '', '', '', '', '', False, False, False, False, False, False, False, 'Capital', 'Córdoba', 'Córdoba', 'https://www.argenprop.com/departamento-en-alquiler-en-cordoba--12535738'], ['140.000', '$', '&plus $21.200expensas', 'Bv Chacabuco 1200, Piso 1', 'Departamento en Alquiler en Nueva Cordoba, Cordoba', 'Nueva Cordoba, Cordoba', '66  m² cubie.', '2 dorm.', '30 años', '1 baño', '3 ambientes', '', '', 'Bueno', 'Contra Frente', False, False, False, False, False, False, False, 'Capital', 'Córdoba', 'Córdoba', 'https://www.argenprop.com/departamento-en-alquiler-en-nueva-cordoba-3-ambientes--12547923'], ['60.000', '$', '', 'Soldado Ruiz 1000', 'Departamento en Alquiler en San Martin, Cordoba', 'San Martin, Cordoba', '45  m² cubie.', '1 dorm.', '', '1 baño', '', '', '', '', '', False, False, False, False, False, False, False, 'Capital', 'Córdoba', 'Córdoba', 'https://www.argenprop.com/departamento-en-alquiler-en-san-martin--11542601'], ['55.000', '$', '', 'Salta 100, Piso 1', 'Departamento en Alquiler en Cordoba, Cordoba Capital', 'Cordoba, Cordoba Capital', '30  m² cubie.', '1 dorm.', '18 años', '1 baño', '', '', '', '', '', False, False, False, False, False, False, False, 'Capital', 'Córdoba', 'Córdoba', 'https://www.argenprop.com/departamento-en-alquiler-en-cordoba--6052987'], ['120.000', '$', '&plus $5.200expensas', 'PotosÍ 1300, Piso 1', 'Departamento en Alquiler en General Pueyrredon, Cordoba', 'General Pueyrredon, Cordoba', '66  m² cubie.', '3 dorm.', '50 años', '1 baño', '4 ambientes', '', '', 'Muy Bueno', 'Contra Frente', False, False, False, False, False, False, False, 'Capital', 'Córdoba', 'Córdoba', 'https://www.argenprop.com/departamento-en-alquiler-en-general-pueyrredon-4-ambientes--11575912'], ['169.000', '$', '&plus $30.000expensas', 'Pistonala', 'Departamento en Alquiler en Manantiales, Cordoba', 'Manantiales, Cordoba', '95  m² cubie.', '2 dorm.', '5 años', '2 baños', '3 ambientes', '1 cocheras', '', 'Excelente', 'Contra Frente', True, False, True, True, False, False, False, 'Capital', 'Córdoba', 'Córdoba', 'https://www.argenprop.com/departamento-en-alquiler-en-manantiales-3-ambientes--12231114'], ['87.000', '$', '&plus $15.000expensas', 'Hipolito Yrigoyen 400, Piso 13', 'Departamento en Alquiler en Nueva Cordoba, Cordoba', 'Nueva Cordoba, Cordoba', '40  m² cubie.', '1 dorm.', '', '1 baño', '', '', '', '', '', False, False, False, False, False, False, False, 'Capital', 'Córdoba', 'Córdoba', 'https://www.argenprop.com/departamento-en-alquiler-en-nueva-cordoba--10405696'], ['140.000', '$', '&plus $21.000expensas', 'Obipo Oro 400, Piso 13', 'Departamento en Alquiler en Nueva Cordoba, Cordoba', 'Nueva Cordoba, Cordoba', '66  m² cubie.', '2 dorm.', '16 años', '1 baño', '3 ambientes', '', '', 'Muy Bueno', 'Frente', False, False, False, False, False, False, False, 'Capital', 'Córdoba', 'Córdoba', 'https://www.argenprop.com/departamento-en-alquiler-en-nueva-cordoba-3-ambientes--12591724'], ['130.000', '$', '&plus $15.000expensas', 'Bazán De Pedraza 3200', 'Departamento en Alquiler en Alto Verde, Cordoba', 'Alto Verde, Cordoba', '50  m² cubie.', '2 dorm.', 'A Estrenar', '2 baños', '3 ambientes', '1 cocheras', '', 'Excelente', '', False, False, False, False, False, False, False, 'Capital', 'Córdoba', 'Córdoba', 'https://www.argenprop.com/departamento-en-alquiler-en-alto-verde-3-ambientes--10874969'], ['150.000', '$', '&plus $7.800expensas', 'Duarte quir ...
# [['45.000', '$', '', 'Salta 200, Piso PB', 'Departamento en Alquiler en San Francisco, San Justo', 'San Francisco, San Justo', '', '2 dorm.', '', '1 baño', '3 ambientes', '', '', '', '', False, False, False, False, False, False, False, 'San Justo', 'Córdoba', 'San Francisco', 'https://www.argenprop.com/departamento-en-alquiler-en-san-francisco-3-ambientes--6770215'], ['85.000', '$', '', 'Av. Illia 2500, Piso 1', 'Departamento en Alquiler en Santa Rita, Villa Carlos Paz', 'Santa Rita, Villa Carlos Paz', '45  m² cubie.', '1 dorm.', '10 años', '1 baño', '2 ambientes', '1 cocheras', '', 'Excelente', 'Interno', False, False, False, False, False, False, False, None, None, None, 'https://www.argenprop.com/departamento-en-alquiler-en-santa-rita-2-ambientes--6634375'], ['1.200', 'USD', '', 'Av H Yrigoyen 400', 'Departamento en Alquiler en Nueva Cordoba, Cordoba', 'Nueva Cordoba, Cordoba', '', '3 dorm.', '', '', '', '', '', '', '', False, False, False, False, False, False, False, 'Capital', 'Córdoba', 'Córdoba', 'https://www.argenprop.com/departamento-en-alquiler-en-nueva-cordoba--12429998'], ['40.000', '$', '', 'Entre Ríos 1700, Piso PA', 'Departamento en Alquiler en San Francisco, San Justo', 'San Francisco, San Justo', '', '2 dorm.', '', '1 baño', '3 ambientes', '', '', 'Muy Bueno', 'Frente', False, False, False, False, False, False, False, 'San Justo', 'Córdoba', 'San Francisco', 'https://www.argenprop.com/departamento-en-alquiler-en-san-francisco-3-ambientes--6768622'], ['110.000', '$', '&plus $22.000expensas', 'Av. Colon al 600', 'Departamento en Alquiler en Centro, Cordoba', 'Centro, Cordoba', '100  m² cubie.', '2 dorm.', '47 años', '2 baños', '5 ambientes', '', '', '', '', False, False, False, False, False, False, False, 'Capital', 'Córdoba', 'Córdoba', 'https://www.argenprop.com/departamento-en-alquiler-en-centro-5-ambientes--12554982'], ['50.000', '$', '', 'Florencio Sanchez 100, Piso PB', 'Departamento en Alquiler en San Francisco, San Justo', 'San Francisco, San Justo', '', '2 dorm.', '', '1 baño', '3 ambientes', '1 cocheras', '', 'Bueno', 'Frente', False, False, False, False, False, False, False, 'San Justo', 'Córdoba', 'San Francisco', 'https://www.argenprop.com/departamento-en-alquiler-en-san-francisco-3-ambientes--6561354'], ['40.000', '$', '', 'Ameghino 200, Piso PB', 'Departamento en Alquiler en San Francisco, San Justo', 'San Francisco, San Justo', '', '1 dorm.', '', '1 baño', '2 ambientes', '', '', '', '', False, False, False, False, False, False, False, 'San Justo', 'Córdoba', 'San Francisco', 'https://www.argenprop.com/departamento-en-alquiler-en-san-francisco-2-ambientes--7846283'], ['115.000', '$', '', 'AV. Maipu 18', 'Departamento en Alquiler en Nueva Cordoba, Cordoba', 'Nueva Cordoba, Cordoba', '50  m² cubie.', '1 dorm.', '20 años', '1 baño', '2 ambientes', '', '', '', '', False, False, False, False, False, False, False, 'Capital', 'Córdoba', 'Córdoba', 'https://www.argenprop.com/departamento-en-alquiler-en-nueva-cordoba-2-ambientes--12556442'], ['80.000', '$', '&plus $7.500expensas', 'Domingo funes al 450', 'Departamento en Alquiler en Guemes, Cordoba', 'Guemes, Cordoba', '50  m² cubie.', '1 dorm.', '10 años', '1 baño', '2 ambientes', '', '', '', '', False, False, False, False, False, False, False, 'Capital', 'Córdoba', 'Córdoba', 'https://www.argenprop.com/departamento-en-alquiler-en-guemes-2-ambientes--12584030'], ['8.400', '$', '', 'SAAVEDRA 100', 'Departamento en Alquiler en Villa Carlos Paz, Punilla', 'Villa Carlos Paz, Punilla', '48  m² cubie.', '1 dorm.', 'A Estrenar', '1 baño', '1 ambiente', '', '', '', '', False, False, False, False, False, False, False, 'Punilla', 'Córdoba', 'Villa Carlos Paz', 'https://www.argenprop.com/departamento-en-alquiler-en-villa-carlos-paz-1-ambiente--5986249'], ['22.000', '$', '', 'DR MARADONA 300', 'Departamento en Alquiler en Malvinas, Villa Carlos Paz', 'Malvinas, Villa Carlos Paz', '56  m² cubie.', '2 dorm.', 'A Estrenar', '1 baño', '2 ambientes', '', '', '', '', False, ...
# [['12.000', '$', '', 'LA RIOJA 100', 'Departamento en Alquiler en Villa Carlos Paz, Punilla', 'Villa Carlos Paz, Punilla', '45  m² cubie.', '1 dorm.', '7 años', '1 baño', '1 ambiente', '', '', '', '', False, False, False, False, False, False, False, 'Punilla', 'Córdoba', 'Villa Carlos Paz', 'https://www.argenprop.com/departamento-en-alquiler-en-villa-carlos-paz-1-ambiente--12503177'], ['120.000', '$', '', 'Jose M Estrada 100, Piso 2', 'Departamento en Alquiler en Nueva Cordoba, Cordoba', 'Nueva Cordoba, Cordoba', '', '1 dorm.', '', '1 baño', '5 ambientes', '', '', '', '', False, False, False, False, False, False, False, 'Capital', 'Córdoba', 'Córdoba', 'https://www.argenprop.com/departamento-en-alquiler-en-nueva-cordoba-5-ambientes--12531539'], ['75.000', '$', '&plus $10.000expensas', '27 de abril 800', 'Departamento en Alquiler en Alberdi, Cordoba', 'Alberdi, Cordoba', '42  m² cubie.', '1 dorm.', '', '1 baño', '2 ambientes', '', '', '', '', False, False, False, False, False, False, False, 'Capital', 'Córdoba', 'Córdoba', 'https://www.argenprop.com/departamento-en-alquiler-en-alberdi-2-ambientes--12542458'], ['150.000', '$', '', 'General Deheza', 'Departamento en Alquiler en General Paz, Cordoba', 'General Paz, Cordoba', '40  m² cubie.', '1 dorm.', 'A Estrenar', '1 baño', '3 ambientes', '', '', '', '', False, False, False, False, False, False, False, 'Capital', 'Córdoba', 'Córdoba', 'https://www.argenprop.com/departamento-en-alquiler-en-general-paz-3-ambientes--12548350'], ['1.300', 'USD', '', 'Jiménez de Lorca 4600', 'Departamento en Alquiler en Cerro De Las Rosas, Cordoba', 'Cerro De Las Rosas, Cordoba', '180  m² cubie.', '2 dorm.', 'A Estrenar', '4 baños', '2 ambientes', '', '', '', '', False, False, False, False, False, False, False, 'Capital', 'Córdoba', 'Córdoba', 'https://www.argenprop.com/departamento-en-alquiler-en-cerro-de-las-rosas-2-ambientes--12558803'], ['95.000', '$', '', 'Mariano fragueiro 2700, Piso PB', 'Departamento en Alquiler en Alta Cordoba, Cordoba', 'Alta Cordoba, Cordoba', '80  m² cubie.', '2 dorm.', 'A Estrenar', '1 baño', '4 ambientes', '', '', '', '', False, False, False, False, False, False, False, 'Capital', 'Córdoba', 'Córdoba', 'https://www.argenprop.com/departamento-en-alquiler-en-alta-cordoba-4-ambientes--12559225'], ['300.000', '$', '&plus $65.836expensas', 'Av. República Popular de China al 1400', 'Departamento en Alquiler en Countries y Barrios Cerrados en Cordoba Capital, Cordoba Capital', 'Countries y Barrios Cerrados en Cordoba Capital, Cordoba Capital', '127  m² cubie.', '2 dorm.', 'A Estrenar', '2 baños', '4 ambientes', '1 cocheras', '', '', '', False, False, False, False, False, False, False, 'Capital', 'Córdoba', 'Córdoba', 'https://www.argenprop.com/departamento-en-alquiler-en-countries-y-barrios-cerrados-en-cordoba-capital-4-ambientes--12561240'], ['90.000', '$', '', 'Corro 600', 'Departamento en Alquiler en Observatorio, Cordoba', 'Observatorio, Cordoba', '', '2 dorm.', '', '1 baño', '3 ambientes', '', '', '', '', False, False, False, False, False, False, False, 'Capital', 'Córdoba', 'Córdoba', 'https://www.argenprop.com/departamento-en-alquiler-en-observatorio-3-ambientes--12563103'], ['40.000', '$', '', 'Intendente Ramon Mestre 2300', 'Departamento en Alquiler en San Martin, Cordoba', 'San Martin, Cordoba', '35  m² cubie.', '1 dorm.', '', '1 baño', '2 ambientes', '', '', 'Bueno', '', False, False, False, False, False, False, False, 'Capital', 'Córdoba', 'Córdoba', 'https://www.argenprop.com/departamento-en-alquiler-en-san-martin-2-ambientes--12563615'], ['150.000', '$', '&plus $13.000expensas', 'Caseros 200, Piso 6', 'Departamento en Alquiler en Centro, Cordoba', 'Centro, Cordoba', '110  m² cubie.', '2 dorm.', '12 años', '1 baño', '4 ambientes', '', '', '', '', False, False, False, False, False, False, False, 'Capital', 'Córdoba', 'Córdoba', 'https://www.argenprop.com/departamento-en-alquiler-en-centro-4-ambientes--12565918'], ['70.000', '$', '&plus $8.000expensas', 'Espora al 2 ...
# [['70.000', '$', '&plus $7.000expensas', 'Deán Funes 1400', 'Departamento en Alquiler en Alberdi, Cordoba', 'Alberdi, Cordoba', '45  m² cubie.', '1 dorm.', '', '1 baño', '2 ambientes', '', '', 'Excelente', 'Frente', False, False, False, False, False, False, False, 'Capital', 'Córdoba', 'Córdoba', 'https://www.argenprop.com/departamento-en-alquiler-en-alberdi-2-ambientes--12585901'], ['50.000', '$', '', 'Podesta , Piso 1', 'Departamento en Alquiler en Los Gigantes, Cordoba', 'Los Gigantes, Cordoba', '57  m² cubie.', '2 dorm.', '', '1 baño', '3 ambientes', '', '', '', '', False, False, False, False, False, False, False, 'Capital', 'Córdoba', 'Córdoba', 'https://www.argenprop.com/departamento-en-alquiler-en-los-gigantes-3-ambientes--12589464'], ['45.000', '$', '', 'Consultar dirección , Piso 11', 'Departamento en Alquiler en San Francisco, San Justo', 'San Francisco, San Justo', '45  m² cubie.', '1 dorm.', '', '1 baño', '2 ambientes', '', '', 'Excelente', 'Frente', False, False, False, False, False, False, False, 'San Justo', 'Córdoba', 'San Francisco', 'https://www.argenprop.com/departamento-en-alquiler-en-san-francisco-2-ambientes--6389721'], ['165.000', '$', '', 'Jardines Del Jockey', 'Departamento en Alquiler en Jardines Del Jockey, Countries y Barrios Cerrados en Cordoba Capital', 'Jardines Del Jockey, Countries y Barrios Cerrados en Cordoba Capital', '170  m² cubie.', '3 dorm.', '10 años', '3 baños', '4 ambientes', '2 cocheras', '', 'Excelente', '', False, False, False, False, False, False, False, 'Capital', 'Córdoba', 'Córdoba', 'https://www.argenprop.com/departamento-en-alquiler-en-jardines-del-jockey-4-ambientes--9253051'], ['195.000', '$', '&plus $1expensas', 'ALQUILER TEMPORAL - Complejo cerrado Opera Luxury con Amenities - 1 dorm - Cochera - Amobablado', 'Departamento en Alquiler en Bajo Palermo, Cordoba', 'Bajo Palermo, Cordoba', '45  m² cubie.', '1 dorm.', '8 años', '1 baño', '2 ambientes', '1 cocheras', '', '', 'Frente', False, True, True, False, True, False, False, 'Capital', 'Córdoba', 'Córdoba', 'https://www.argenprop.com/departamento-en-alquiler-en-bajo-palermo-2-ambientes--11582748'], ['8.000', '$', '', 'C.paz V.del Lago,san Gabriel', 'Departamento en Alquiler en Villa Del Lago, Villa Carlos Paz', 'Villa Del Lago, Villa Carlos Paz', '45  m² cubie.', '1 dorm.', 'A Estrenar', '1 baño', '2 ambientes', '1 cocheras', '', 'Excelente', 'Frente', True, False, True, True, False, False, False, 'Punilla', 'Córdoba', 'Villa Carlos Paz', 'https://www.argenprop.com/departamento-en-alquiler-en-villa-del-lago-2-ambientes--7800411'], ['72.000', '$', '', 'ALQUILER LOCAL: Carlos Pellegrini al 800. VILLA ALLENDE', 'Departamento en Alquiler en Villa Allende, Colon', 'Villa Allende, Colon', '', 'Monoam.', 'A Estrenar', '', '', '', '', '', '', False, False, False, False, False, False, False, 'Colón', 'Córdoba', 'Villa Allende', 'https://www.argenprop.com/departamento-en-alquiler-en-villa-allende--12084663'], ['290.000', '$', '', 'Formosa 0', 'Departamento en Alquiler en Villa Allende, Colon', 'Villa Allende, Colon', '380  m² cubie.', '4 dorm.', '11 años', '2 baños', '4 ambientes', '', '1 toilettes', '', '', False, False, False, False, False, False, False, 'Capital', 'Córdoba', 'Córdoba', 'https://www.argenprop.com/departamento-en-alquiler-en-villa-allende-4-ambientes--12128894'], ['16.000', '$', '&plus $7.200expensas', 'La Rioja 0', 'Departamento en Alquiler en Centro, Cordoba', 'Centro, Cordoba', '22  m² cubie.', 'Monoam.', '33 años', '1 baño', '1 ambiente', '', '', 'Muy Bueno', '', False, False, False, False, False, False, False, 'Capital', 'Córdoba', 'Córdoba', 'https://www.argenprop.com/departamento-en-alquiler-en-centro-1-ambiente--12090156'], ['180.000', '$', '&plus $48.000expensas', 'Av. Santa Fe al 600', 'Departamento en Alquiler en Cordoba, Cordoba Capital', 'Cordoba, Cordoba Capital', '115  m² cubie.', '3 dorm.', '12 años', '2 baños', '5 ambientes', '1 cocheras', '', '', '', False, True, True, False, False, False, False, ' ...
# [['100.000', '$', '&plus $9.655expensas', 'Rosario de Santa Fe y David Luque', 'Departamento en Alquiler en General Paz, Cordoba', 'General Paz, Cordoba', '45  m² cubie.', '1 dorm.', '6 años', '1 baño', '2 ambientes', '', '', '', '', False, False, False, False, False, False, False, 'Capital', 'Córdoba', 'Córdoba', 'https://www.argenprop.com/departamento-en-alquiler-en-general-paz-2-ambientes--12527418'], ['130.000', '$', '&plus $10.000expensas', 'De Los Extremeños 4900', 'Departamento en Alquiler en Jardin Claret, Cordoba', 'Jardin Claret, Cordoba', '89  m² cubie.', '2 dorm.', 'A Estrenar', '1 baño', '3 ambientes', '1 cocheras', '', 'Excelente', 'Lateral', True, False, True, True, False, False, False, 'Capital', 'Córdoba', 'Córdoba', 'https://www.argenprop.com/departamento-en-alquiler-en-jardin-claret-3-ambientes--12476776'], ['250.000', '$', '&plus $45.000expensas', 'Calandria 100', 'Departamento en Alquiler en Chateau Carreras, Cordoba', 'Chateau Carreras, Cordoba', '88  m² cubie.', '3 dorm.', '1 año', '2 baños', '5 ambientes', '', '', '', '', False, False, False, False, False, False, False, 'Capital', 'Córdoba', 'Córdoba', 'https://www.argenprop.com/departamento-en-alquiler-en-chateau-carreras-5-ambientes--12529213'], ['140.000', '$', '', 'Calle Las Toscas 0', 'Departamento en Alquiler en Countries y Barrios Cerrados en Cordoba Capital, Cordoba Capital', 'Countries y Barrios Cerrados en Cordoba Capital, Cordoba Capital', '110  m² cubie.', '3 dorm.', 'A Estrenar', '2 baños', '5 ambientes', '1 cocheras', '2 toilettes', '', '', False, False, False, False, False, False, False, 'Capital', 'Córdoba', 'Córdoba', 'https://www.argenprop.com/departamento-en-alquiler-en-countries-y-barrios-cerrados-en-cordoba-capital-5-ambientes--12533333'], ['350.000', '$', '', 'Alquiler temporal en Jardín Claret Summun - 2 dormitorios  - Asador', 'Departamento en Alquiler en Cordoba, Cordoba Capital', 'Cordoba, Cordoba Capital', '90  m² cubie.', '2 dorm.', 'A Estrenar', '2 baños', '3 ambientes', '2 cocheras', '', '', '', False, False, False, False, False, False, False, 'Capital', 'Córdoba', 'Córdoba', 'https://www.argenprop.com/departamento-en-alquiler-en-cordoba-3-ambientes--12543931'], ['20.000', '$', '', 'San Lorenzo al 100', 'Departamento en Alquiler en Nueva Cordoba, Cordoba', 'Nueva Cordoba, Cordoba', '60  m² cubie.', '2 dorm.', '10 años', '2 baños', '3 ambientes', '', '', '', '', False, False, False, False, False, False, False, 'Capital', 'Córdoba', 'Córdoba', 'https://www.argenprop.com/departamento-en-alquiler-en-nueva-cordoba-3-ambientes--12552487'], ['85.000', '$', '&plus $5.500expensas', 'Lima al 1000', 'Departamento en Alquiler en General Paz, Cordoba', 'General Paz, Cordoba', '35  m² cubie.', '1 dorm.', '7 años', '1 baño', '2 ambientes', '', '', '', '', False, False, True, False, False, False, False, 'Capital', 'Córdoba', 'Córdoba', 'https://www.argenprop.com/departamento-en-alquiler-en-general-paz-2-ambientes--12557849'], ['300.000', '$', '&plus $120.000expensas', 'CAVENDISH 6000', 'Departamento en Alquiler en Villa Belgrano, Cordoba', 'Villa Belgrano, Cordoba', '100  m² cubie.', '3 dorm.', 'A Estrenar', '2 baños', '3 ambientes', '', '', '', '', False, False, False, False, False, False, False, 'Capital', 'Córdoba', 'Córdoba', 'https://www.argenprop.com/departamento-en-alquiler-en-villa-belgrano-3-ambientes--12558973'], ['145.000', '$', '&plus $12.900expensas', 'Estrada y Buenos Aires', 'Departamento en Alquiler en Nueva Cordoba, Cordoba', 'Nueva Cordoba, Cordoba', '46  m² cubie.', '1 dorm.', '11 años', '1 baño', '2 ambientes', '', '', '', '', False, False, False, False, False, False, False, 'Capital', 'Córdoba', 'Córdoba', 'https://www.argenprop.com/departamento-en-alquiler-en-nueva-cordoba-2-ambientes--12559004'], ['90.000', '$', '&plus $12.000expensas', 'Ovidio Lagos 100, Piso 2', 'Departamento en Alquiler en General Paz, Cordoba', 'General Paz, Cordoba', '49  m² cubie.', '1 dorm.', '6 años', '1 baño', '2 ambientes', '', '', '', 'Con ...
# [['120.000', '$', '&plus $15.144expensas', 'Pueyrredon y Obispo Trejo', 'Departamento en Alquiler en Nueva Cordoba, Cordoba', 'Nueva Cordoba, Cordoba', '38  m² cubie.', '1 dorm.', '7 años', '1 baño', '2 ambientes', '', '', '', '', False, False, False, False, False, False, False, 'Capital', 'Córdoba', 'Córdoba', 'https://www.argenprop.com/departamento-en-alquiler-en-nueva-cordoba-2-ambientes--12587291'], ['120.000', '$', '&plus $10.164expensas', 'Independencia y Ambrosio Olmos', 'Departamento en Alquiler en Nueva Cordoba, Cordoba', 'Nueva Cordoba, Cordoba', '45  m² cubie.', '1 dorm.', '15 años', '1 baño', '2 ambientes', '', '', '', '', False, False, False, False, False, False, False, 'Capital', 'Córdoba', 'Córdoba', 'https://www.argenprop.com/departamento-en-alquiler-en-nueva-cordoba-2-ambientes--12588181'], ['88.000', '$', '&plus $8.500expensas', 'Santiago Temple 100', 'Departamento en Alquiler en Nueva Cordoba, Cordoba', 'Nueva Cordoba, Cordoba', '38  m² cubie.', '1 dorm.', '20 años', '1 baño', '2 ambientes', '', '', 'Muy Bueno', 'Frente', False, False, False, False, False, False, False, 'Capital', 'Córdoba', 'Córdoba', 'https://www.argenprop.com/departamento-en-alquiler-en-nueva-cordoba-2-ambientes--12588469'], ['45.000', '$', '', 'Urrutia 500', 'Departamento en Alquiler en Alberdi, Cordoba', 'Alberdi, Cordoba', '25  m² cubie.', 'Monoam.', '30 años', '', '1 ambiente', '', '', '', '', False, False, False, False, False, False, False, 'Capital', 'Córdoba', 'Córdoba', 'https://www.argenprop.com/departamento-en-alquiler-en-alberdi-1-ambiente--12591233'], ['75.000', '$', '', 'Hipolito Vieytes 100', 'Departamento en Alquiler en Alberdi, Cordoba', 'Alberdi, Cordoba', '40  m² cubie.', '1 dorm.', '20 años', '1 baño', '3 ambientes', '', '', '', '', False, False, False, False, False, False, False, 'Capital', 'Córdoba', 'Córdoba', 'https://www.argenprop.com/departamento-en-alquiler-en-alberdi-3-ambientes--12591431'], ['115.000', '$', '&plus $13.596expensas', 'Poeta Lugones y Derqui', 'Departamento en Alquiler en Nueva Cordoba, Cordoba', 'Nueva Cordoba, Cordoba', '44  m² cubie.', '1 dorm.', '16 años', '1 baño', '2 ambientes', '', '', '', '', False, False, False, False, False, False, False, 'Capital', 'Córdoba', 'Córdoba', 'https://www.argenprop.com/departamento-en-alquiler-en-nueva-cordoba-2-ambientes--12591587'], ['125.000', '$', '&plus $12.159expensas', 'Obispo Salguero y Rondeau', 'Departamento en Alquiler en Nueva Cordoba, Cordoba', 'Nueva Cordoba, Cordoba', '41  m² cubie.', '1 dorm.', '20 años', '1 baño', '2 ambientes', '', '', '', '', False, False, False, False, False, False, False, 'Capital', 'Córdoba', 'Córdoba', 'https://www.argenprop.com/departamento-en-alquiler-en-nueva-cordoba-2-ambientes--12593064']]

# %%
import pandas as pd
df = pd.DataFrame(properties_all,columns=[['price','currency','expenses','address','title','location','superficie','dormitorio','antiguedad','banos','ambientes','cocheras','toilett','estado','disposicion','parr','gym','pool','solarium','juegos','salon','ascensor','departamento','provincia','municipio','url_link']])

# %%
df
# Out:
#        price currency               expenses                     address  \
# 0     75.000        $   &plus $9.600expensas  Duarte Quiros 2500, Piso 6
# 1    130.000        $                           Buenos Aires 400, Piso 5
# 2    140.000        $  &plus $21.200expensas   Bv Chacabuco 1200, Piso 1
# 3     60.000        $                                  Soldado Ruiz 1000
# 4     55.000        $                                  Salta 100, Piso 1
# ..       ...      ...                    ...                         ...
# 98    88.000        $   &plus $8.500expensas         Santiago Temple 100
# 99    45.000        $                                        Urrutia 500
# 100   75.000        $                               Hipolito Vieytes 100
# 101  115.000        $  &plus $13.596expensas      Poeta Lugones y Derqui
# 102  125.000        $  &plus $12.159expensas   Obispo Salguero y Rondeau
#
#                                                  title  \
# 0    Departamento en Alquiler en Alto Alberdi, Cordoba
# 1    Departamento en Alquiler en Cordoba, Cordoba C...
# 2    Departamento en Alquiler en Nueva Cordoba, Cor...
# 3      Departamento en Alquiler en San Martin, Cordoba
# 4    Departamento en Alquiler en Cordoba, Cordoba C...
# ..                                                 ...
# 98   Departamento en Alquiler en Nueva Cordoba, Cor...
# 99        Departamento en Alquiler en Alberdi, Cordoba
# 100       Departamento en Alquiler en Alberdi, Cordoba
# 101  Departamento en Alquiler en Nueva Cordoba, Cor...
# 102  Departamento en Alquiler en Nueva Cordoba, Cor...
#
#                      location     superficie dormitorio antiguedad    banos  \
# 0       Alto Alberdi, Cordoba  52  m² cubie.    1 dorm.     5 años   1 baño
# 1    Cordoba, Cordoba Capital                   2 dorm.    25 años  2 baños
# 2      Nueva Cordoba, Cordoba  66  m² cubie.    2 dorm.    30 años   1 baño
# 3         San Martin, Cordoba  45  m² cubie.    1 dorm.              1 baño
# 4    Cordoba, Cordoba Capital  30  m² cubie.    1 dorm.    18 años   1 baño
# ..                        ...            ...        ...        ...      ...
# 98     Nueva Cordoba, Cordoba  38  m² cubie.    1 dorm.    20 años   1 baño
# 99           Alberdi, Cordoba  25  m² cubie.    Monoam.    30 años
# 100          Alberdi, Cordoba  40  m² cubie.    1 dorm.    20 años   1 baño
# 101    Nueva Cordoba, Cordoba  44  m² cubie.    1 dorm.    16 años   1 baño
# 102    Nueva Cordoba, Cordoba  41  m² cubie.    1 dorm.    20 años   1 baño
#
#      ...    gym   pool solarium juegos  salon ascensor departamento provincia  \
# 0    ...  False  False    False  False  False    False      Capital   Córdoba
# 1    ...  False  False    False  False  False    False      Capital   Córdoba
# 2    ...  False  False    False  False  False    False      Capital   Córdoba
# 3    ...  False  False    False  False  False    False      Capital   Córdoba
# 4    ...  False  False    False  False  False    False      Capital   Córdoba
# ..   ...    ...    ...      ...    ...    ...      ...          ...       ...
# 98   ...  False  False    False  False  False    False      Capital   Córdoba
# 99   ...  False  False    False  False  False    False      Capital   Córdoba
# 100  ...  False  False    False  False  False    False      Capital   Córdoba
# 101  ...  False  False    False  False  False    False      Capital   Córdoba
# 102  ...  False  False    False  False  False    False      Capital   Córdoba
#
#     municipio                                           url_link
# 0     Córdoba  https://www.argenprop.com/departamento-en-alqu...
# 1     Córdoba  https://www.argenprop.com/departamento-en-alqu...
# 2     Córdoba  https://www.argenprop.com/departamento-en-alqu...
# 3     Córdoba  https://www.argenprop.com/departamento-en-alqu...
# 4     Córdoba  https://www.argenprop.com/departamento-en-alqu...
# ..        ...                                                ...
# 98    Córdoba  https://www.argenprop.com/departamento-en-alqu...
# 99    Córdoba  https://www.argenprop.com/departamento-en-alqu...
# 100   Córdoba  https://www.argenprop.com/departamento-en-alqu...
# 101   Córdoba  https://www.argenprop.com/departamento-en-alqu...
# 102   Córdoba  https://www.argenprop.com/departamento-en-alqu...
#
# [103 rows x 26 columns]

# %%
df.columns = ['price','currency','expenses','address','title','location','superficie','dormitorio','antiguedad','banos','ambientes','cocheras','toilett','estado','disposicion','parr','gym','pool','solarium','juegos','salon','ascensor','departamento','provincia','municipio','url_link']

# %%
def change_to_type(df,colum_name,type):
  df[colum_name]=df[colum_name].str.replace('.', '')
  df[colum_name] = df[colum_name].astype(type)

# %%
def change_to_numeric(df,colum_name):
  df[df[colum_name]!=''][colum_name] = pd.to_numeric(df[df[colum_name]!=''][colum_name], errors='coerce')
  df[colum_name] = pd.to_numeric(df[colum_name], errors='coerce')

# %%
def extract_number(text):
  import re
  if isinstance(text, str):
    if '.' in text:
      text = text.replace('.', '')
    match = re.search(r'\d+', text)
    if match:
        return int(match.group(0))
  return text

# %%
def process_column(df, column_name, reference_value=None):
    if column_name in df.columns:
      df[column_name] = df[column_name].apply(lambda x: 0 if x == reference_value else extract_number(x))
    else:
      print("La columna especificada no existe en el DataFrame")

# %%
pd.set_option('display.float_format', lambda x: '%.0f' % x)

# %%
df.dormitorio.unique()
# Out:
# array(['1 dorm.', '2 dorm.', '3 dorm.', '5 dorm.', 'Monoam.', '4 dorm.'],
#       dtype=object)

# %%
df.antiguedad.unique()
# Out:
# array(['5 años', '25 años', '30 años', '', '18 años', '50 años',
#        '16 años', 'A Estrenar', '8 años', '20 años', '3 años', '10 años',
#        '47 años', '1 año', '4 años', '7 años', '12 años', '15 años',
#        '11 años', '33 años', '2 años', '6 años', '51 años'], dtype=object)

# %%
process_column(df, 'dormitorio', 'Monoam.')
process_column(df, 'antiguedad', 'A Estrenar')
process_column(df, 'expenses')
process_column(df, 'superficie')
process_column(df, 'banos')
process_column(df, 'ambientes')
process_column(df, 'cocheras')
process_column(df, 'toilett')

# %%
df
# Out:
#        price currency expenses                     address  \
# 0     75.000        $     9600  Duarte Quiros 2500, Piso 6
# 1    130.000        $             Buenos Aires 400, Piso 5
# 2    140.000        $    21200   Bv Chacabuco 1200, Piso 1
# 3     60.000        $                    Soldado Ruiz 1000
# 4     55.000        $                    Salta 100, Piso 1
# ..       ...      ...      ...                         ...
# 98    88.000        $     8500         Santiago Temple 100
# 99    45.000        $                          Urrutia 500
# 100   75.000        $                 Hipolito Vieytes 100
# 101  115.000        $    13596      Poeta Lugones y Derqui
# 102  125.000        $    12159   Obispo Salguero y Rondeau
#
#                                                  title  \
# 0    Departamento en Alquiler en Alto Alberdi, Cordoba
# 1    Departamento en Alquiler en Cordoba, Cordoba C...
# 2    Departamento en Alquiler en Nueva Cordoba, Cor...
# 3      Departamento en Alquiler en San Martin, Cordoba
# 4    Departamento en Alquiler en Cordoba, Cordoba C...
# ..                                                 ...
# 98   Departamento en Alquiler en Nueva Cordoba, Cor...
# 99        Departamento en Alquiler en Alberdi, Cordoba
# 100       Departamento en Alquiler en Alberdi, Cordoba
# 101  Departamento en Alquiler en Nueva Cordoba, Cor...
# 102  Departamento en Alquiler en Nueva Cordoba, Cor...
#
#                      location superficie  dormitorio antiguedad banos  ...  \
# 0       Alto Alberdi, Cordoba         52           1          5     1  ...
# 1    Cordoba, Cordoba Capital                      2         25     2  ...
# 2      Nueva Cordoba, Cordoba         66           2         30     1  ...
# 3         San Martin, Cordoba         45           1                1  ...
# 4    Cordoba, Cordoba Capital         30           1         18     1  ...
# ..                        ...        ...         ...        ...   ...  ...
# 98     Nueva Cordoba, Cordoba         38           1         20     1  ...
# 99           Alberdi, Cordoba         25           0         30        ...
# 100          Alberdi, Cordoba         40           1         20     1  ...
# 101    Nueva Cordoba, Cordoba         44           1         16     1  ...
# 102    Nueva Cordoba, Cordoba         41           1         20     1  ...
#
#        gym   pool solarium juegos  salon  ascensor  departamento  provincia  \
# 0    False  False    False  False  False     False       Capital    Córdoba
# 1    False  False    False  False  False     False       Capital    Córdoba
# 2    False  False    False  False  False     False       Capital    Córdoba
# 3    False  False    False  False  False     False       Capital    Córdoba
# 4    False  False    False  False  False     False       Capital    Córdoba
# ..     ...    ...      ...    ...    ...       ...           ...        ...
# 98   False  False    False  False  False     False       Capital    Córdoba
# 99   False  False    False  False  False     False       Capital    Córdoba
# 100  False  False    False  False  False     False       Capital    Córdoba
# 101  False  False    False  False  False     False       Capital    Córdoba
# 102  False  False    False  False  False     False       Capital    Córdoba
#
#      municipio                                           url_link
# 0      Córdoba  https://www.argenprop.com/departamento-en-alqu...
# 1      Córdoba  https://www.argenprop.com/departamento-en-alqu...
# 2      Córdoba  https://www.argenprop.com/departamento-en-alqu...
# 3      Córdoba  https://www.argenprop.com/departamento-en-alqu...
# 4      Córdoba  https://www.argenprop.com/departamento-en-alqu...
# ..         ...                                                ...
# 98     Córdoba  https://www.argenprop.com/departamento-en-alqu...
# 99     Córdoba  https://www.argenprop.com/departamento-en-alqu...
# 100    Córdoba  https://www.argenprop.com/departamento-en-alqu...
# 101    Córdoba  https://www.argenprop.com/departamento-en-alqu...
# 102    Córdoba  https://www.argenprop.com/departamento-en-alqu...
#
# [103 rows x 26 columns]

# %%
df[['localidad_barrio','provincia_region']] = df['location'].str.split(',',expand=True).apply(lambda x: x.str.strip())

# %%
df['parr']=df['parr'].apply(lambda x: 1 if x == True else 0)

# %%
df['gym']=df['gym'].apply(lambda x: 1 if x == True else 0)

# %%
df['pool'] = df['pool'].apply(lambda x: 1 if x == True else 0)

# %%
df['solarium']=df['solarium'].apply(lambda x: 1 if x == True else 0)

# %%
df['juegos']=df['juegos'].apply(lambda x: 1 if x == True else 0)

# %%
df['salon']=df['salon'].apply(lambda x: 1 if x == True else 0)

# %%
df['ascensor']=df['ascensor'].apply(lambda x: 1 if x == True else 0)

# %%
df
# Out:
#        price currency expenses                     address  \
# 0     75.000        $     9600  Duarte Quiros 2500, Piso 6
# 1    130.000        $             Buenos Aires 400, Piso 5
# 2    140.000        $    21200   Bv Chacabuco 1200, Piso 1
# 3     60.000        $                    Soldado Ruiz 1000
# 4     55.000        $                    Salta 100, Piso 1
# ..       ...      ...      ...                         ...
# 98    88.000        $     8500         Santiago Temple 100
# 99    45.000        $                          Urrutia 500
# 100   75.000        $                 Hipolito Vieytes 100
# 101  115.000        $    13596      Poeta Lugones y Derqui
# 102  125.000        $    12159   Obispo Salguero y Rondeau
#
#                                                  title  \
# 0    Departamento en Alquiler en Alto Alberdi, Cordoba
# 1    Departamento en Alquiler en Cordoba, Cordoba C...
# 2    Departamento en Alquiler en Nueva Cordoba, Cor...
# 3      Departamento en Alquiler en San Martin, Cordoba
# 4    Departamento en Alquiler en Cordoba, Cordoba C...
# ..                                                 ...
# 98   Departamento en Alquiler en Nueva Cordoba, Cor...
# 99        Departamento en Alquiler en Alberdi, Cordoba
# 100       Departamento en Alquiler en Alberdi, Cordoba
# 101  Departamento en Alquiler en Nueva Cordoba, Cor...
# 102  Departamento en Alquiler en Nueva Cordoba, Cor...
#
#                      location superficie  dormitorio antiguedad banos  ...  \
# 0       Alto Alberdi, Cordoba         52           1          5     1  ...
# 1    Cordoba, Cordoba Capital                      2         25     2  ...
# 2      Nueva Cordoba, Cordoba         66           2         30     1  ...
# 3         San Martin, Cordoba         45           1                1  ...
# 4    Cordoba, Cordoba Capital         30           1         18     1  ...
# ..                        ...        ...         ...        ...   ...  ...
# 98     Nueva Cordoba, Cordoba         38           1         20     1  ...
# 99           Alberdi, Cordoba         25           0         30        ...
# 100          Alberdi, Cordoba         40           1         20     1  ...
# 101    Nueva Cordoba, Cordoba         44           1         16     1  ...
# 102    Nueva Cordoba, Cordoba         41           1         20     1  ...
#
#     solarium juegos salon ascensor departamento  provincia  municipio  \
# 0          0      0     0        0      Capital    Córdoba    Córdoba
# 1          0      0     0        0      Capital    Córdoba    Córdoba
# 2          0      0     0        0      Capital    Córdoba    Córdoba
# 3          0      0     0        0      Capital    Córdoba    Córdoba
# 4          0      0     0        0      Capital    Córdoba    Córdoba
# ..       ...    ...   ...      ...          ...        ...        ...
# 98         0      0     0        0      Capital    Córdoba    Córdoba
# 99         0      0     0        0      Capital    Córdoba    Córdoba
# 100        0      0     0        0      Capital    Córdoba    Córdoba
# 101        0      0     0        0      Capital    Córdoba    Córdoba
# 102        0      0     0        0      Capital    Córdoba    Córdoba
#
#                                               url_link  localidad_barrio  \
# 0    https://www.argenprop.com/departamento-en-alqu...      Alto Alberdi
# 1    https://www.argenprop.com/departamento-en-alqu...           Cordoba
# 2    https://www.argenprop.com/departamento-en-alqu...     Nueva Cordoba
# 3    https://www.argenprop.com/departamento-en-alqu...        San Martin
# 4    https://www.argenprop.com/departamento-en-alqu...           Cordoba
# ..                                                 ...               ...
# 98   https://www.argenprop.com/departamento-en-alqu...     Nueva Cordoba
# 99   https://www.argenprop.com/departamento-en-alqu...           Alberdi
# 100  https://www.argenprop.com/departamento-en-alqu...           Alberdi
# 101  https://www.argenprop.com/departamento-en-alqu...     Nueva Cordoba
# 102  https://www.argenprop.com/departamento-en-alqu...     Nueva Cordoba
#
#      provincia_region
# 0             Cordoba
# 1     Cordoba Capital
# 2             Cordoba
# 3             Cordoba
# 4     Cordoba Capital
# ..                ...
# 98            Cordoba
# 99            Cordoba
# 100           Cordoba
# 101           Cordoba
# 102           Cordoba
#
# [103 rows x 28 columns]

# %%
df.rename(columns={'price': 'precio', 'currency': 'moneda', 'address': 'direccion','title':'titulo','location':'ubicacion','parr':'parrilla','gym':'gimnasio','pool':'pileta','juegos':'playroom','salon':'quincho'}, inplace=True)

# %%
change_to_type(df,'precio',float)
# Out:
# <ipython-input-200-cff8684acbb7>:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df[colum_name]=df[colum_name].str.replace('.', '')

# %%
change_to_numeric(df,'expenses')
change_to_numeric(df,'superficie')
change_to_numeric(df,'dormitorio')
change_to_numeric(df,'antiguedad')
change_to_numeric(df,'banos')
change_to_numeric(df,'ambientes')
change_to_numeric(df,'cocheras')
change_to_numeric(df,'toilett')
# Out:
# <ipython-input-201-1c56eeeb05e3>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[df[colum_name]!=''][colum_name] = pd.to_numeric(df[df[colum_name]!=''][colum_name], errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103 entries, 0 to 102
# Data columns (total 28 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   precio            103 non-null    float64
#  1   moneda            103 non-null    object
#  2   expenses          49 non-null     float64
#  3   direccion         103 non-null    object
#  4   titulo            103 non-null    object
#  5   ubicacion         103 non-null    object
#  6   superficie        87 non-null     float64
#  7   dormitorio        103 non-null    int64
#  8   antiguedad        76 non-null     float64
#  9   banos             100 non-null    float64
#  10  ambientes         95 non-null     float64
#  11  cocheras          23 non-null     float64
#  12  toilett           3 non-null      float64
#  13  estado            103 non-null    object
#  14  disposicion       103 non-null    object
#  15  parrilla          103 non-null    int64
#  16  gimnasio          103 non-null    int64
#  17  pileta            103 non-null    int64
#  18  solarium          103 non-null    int64
#  19  playroom          103 non-null    int64
#  20  quincho           103 non-null    int64
#  21  ascensor          103 non-null    int64
#  22  departamento      102 non-null    object
#  23  provincia         102 non-null    object
#  24  municipio         102 non-null    object
#  25  url_link          103 non-null    object
#  26  localidad_barrio  103 non-null    object
#  27  provincia_region  103 non-null    object
# dtypes: float64(8), int64(8), object(12)
# memory usage: 22.7+ KB

# %%
df.replace(to_replace='', value=pd.NaT, inplace=True)

# %%
df.municipio
# Out:
# 0      Córdoba
# 1      Córdoba
# 2      Córdoba
# 3      Córdoba
# 4      Córdoba
#         ...
# 98     Córdoba
# 99     Córdoba
# 100    Córdoba
# 101    Córdoba
# 102    Córdoba
# Name: municipio, Length: 103, dtype: object

# %%
df.describe()
# Out:
#        precio  expenses  superficie  dormitorio  antiguedad  banos  ambientes  \
# count     103        49          87         103          76    100         95
# mean    97344     17512          68           2          10      1          3
# std     77226     19853          51           1          12      1          1
# min      1200         1          22           0           0      1          1
# 25%     45000      8000          42           1           0      1          2
# 50%     80000     12000          49           1           6      1          2
# 75%    135000     20000          78           2          18      1          3
# max    420000    120000         380           5          51      5          7
#
#        cocheras  toilett  parrilla  gimnasio  pileta  solarium  playroom  \
# count        23        3       103       103     103       103       103
# mean          1        1         0         0       0         0         0
# std           0        1         0         0       0         0         0
# min           1        1         0         0       0         0         0
# 25%           1        1         0         0       0         0         0
# 50%           1        1         0         0       0         0         0
# 75%           1        2         0         0       0         0         0
# max           2        2         1         1       1         1         1
#
#        quincho  ascensor
# count      103       103
# mean         0         0
# std          0         0
# min          0         0
# 25%          0         0
# 50%          0         0
# 75%          0         0
# max          0         0

# %%
df
# Out:
#      precio moneda  expenses                   direccion  \
# 0     75000      $      9600  Duarte Quiros 2500, Piso 6
# 1    130000      $       NaN    Buenos Aires 400, Piso 5
# 2    140000      $     21200   Bv Chacabuco 1200, Piso 1
# 3     60000      $       NaN           Soldado Ruiz 1000
# 4     55000      $       NaN           Salta 100, Piso 1
# ..      ...    ...       ...                         ...
# 98    88000      $      8500         Santiago Temple 100
# 99    45000      $       NaN                 Urrutia 500
# 100   75000      $       NaN        Hipolito Vieytes 100
# 101  115000      $     13596      Poeta Lugones y Derqui
# 102  125000      $     12159   Obispo Salguero y Rondeau
#
#                                                 titulo  \
# 0    Departamento en Alquiler en Alto Alberdi, Cordoba
# 1    Departamento en Alquiler en Cordoba, Cordoba C...
# 2    Departamento en Alquiler en Nueva Cordoba, Cor...
# 3      Departamento en Alquiler en San Martin, Cordoba
# 4    Departamento en Alquiler en Cordoba, Cordoba C...
# ..                                                 ...
# 98   Departamento en Alquiler en Nueva Cordoba, Cor...
# 99        Departamento en Alquiler en Alberdi, Cordoba
# 100       Departamento en Alquiler en Alberdi, Cordoba
# 101  Departamento en Alquiler en Nueva Cordoba, Cor...
# 102  Departamento en Alquiler en Nueva Cordoba, Cor...
#
#                     ubicacion  superficie  dormitorio  antiguedad  banos  ...  \
# 0       Alto Alberdi, Cordoba          52           1           5      1  ...
# 1    Cordoba, Cordoba Capital         NaN           2          25      2  ...
# 2      Nueva Cordoba, Cordoba          66           2          30      1  ...
# 3         San Martin, Cordoba          45           1         NaN      1  ...
# 4    Cordoba, Cordoba Capital          30           1          18      1  ...
# ..                        ...         ...         ...         ...    ...  ...
# 98     Nueva Cordoba, Cordoba          38           1          20      1  ...
# 99           Alberdi, Cordoba          25           0          30    NaN  ...
# 100          Alberdi, Cordoba          40           1          20      1  ...
# 101    Nueva Cordoba, Cordoba          44           1          16      1  ...
# 102    Nueva Cordoba, Cordoba          41           1          20      1  ...
#
#      solarium  playroom  quincho ascensor departamento  provincia  municipio  \
# 0           0         0        0        0      Capital    Córdoba    Córdoba
# 1           0         0        0        0      Capital    Córdoba    Córdoba
# 2           0         0        0        0      Capital    Córdoba    Córdoba
# 3           0         0        0        0      Capital    Córdoba    Córdoba
# 4           0         0        0        0      Capital    Córdoba    Córdoba
# ..        ...       ...      ...      ...          ...        ...        ...
# 98          0         0        0        0      Capital    Córdoba    Córdoba
# 99          0         0        0        0      Capital    Córdoba    Córdoba
# 100         0         0        0        0      Capital    Córdoba    Córdoba
# 101         0         0        0        0      Capital    Córdoba    Córdoba
# 102         0         0        0        0      Capital    Córdoba    Córdoba
#
#                                               url_link  localidad_barrio  \
# 0    https://www.argenprop.com/departamento-en-alqu...      Alto Alberdi
# 1    https://www.argenprop.com/departamento-en-alqu...           Cordoba
# 2    https://www.argenprop.com/departamento-en-alqu...     Nueva Cordoba
# 3    https://www.argenprop.com/departamento-en-alqu...        San Martin
# 4    https://www.argenprop.com/departamento-en-alqu...           Cordoba
# ..                                                 ...               ...
# 98   https://www.argenprop.com/departamento-en-alqu...     Nueva Cordoba
# 99   https://www.argenprop.com/departamento-en-alqu...           Alberdi
# 100  https://www.argenprop.com/departamento-en-alqu...           Alberdi
# 101  https://www.argenprop.com/departamento-en-alqu...     Nueva Cordoba
# 102  https://www.argenprop.com/departamento-en-alqu...     Nueva Cordoba
#
#      provincia_region
# 0             Cordoba
# 1     Cordoba Capital
# 2             Cordoba
# 3             Cordoba
# 4     Cordoba Capital
# ..                ...
# 98            Cordoba
# 99            Cordoba
# 100           Cordoba
# 101           Cordoba
# 102           Cordoba
#
# [103 rows x 28 columns]

# %%
def extract_dolar_price(url):
  request = requests.get(url)
  if request.status_code == 200:
    json_data = request.json()
  return json_data['blue']['value_buy']

# %%
dolar_price = extract_dolar_price('https://api.bluelytics.com.ar/v2/latest')

# %%
df.loc[df['moneda']=='USD',['precio']] = df.loc[df['moneda']=='USD',['precio']] * dolar_price

# %%
df.loc[df['moneda']=='USD',['moneda']] = '$'

# %%
df[df.duplicated(subset=['precio','direccion','titulo','ubicacion'])].sort_values(by='titulo')
# Out:
# Empty DataFrame
# Columns: [precio, moneda, expenses, direccion, titulo, ubicacion, superficie, dormitorio, antiguedad, banos, ambientes, cocheras, toilett, estado, disposicion, parrilla, gimnasio, pileta, solarium, playroom, quincho, ascensor, departamento, provincia, municipio, url_link, localidad_barrio, provincia_region]
# Index: []
#
# [0 rows x 28 columns]

# %%
df.drop_duplicates(subset=['precio','direccion','titulo','ubicacion'],inplace=True)

# %%
df.to_csv('web_scrapping_all_result.csv',index=False)
